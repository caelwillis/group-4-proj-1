# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

# %%
ev_path = 'Resources/Clean_EV_Data.csv'
ev_df = pd.read_csv(ev_path)
# ev_df.head()
census_path = 'Resources/2022_census'
cen_df = pd.read_csv(census_path)

# %%
# merge census and EV data in order to compute regression and relationships
cen_df = cen_df.rename(columns={'WA Zipcode':'Postal Code'})
ev_cen = cen_df.merge(ev_df, on='Postal Code').reset_index()
# clean dataframe to include only the columns we are working with
clean_merged_df = ev_cen[['Census Year',
                          'Postal Code',
                          'Population',
                          'Median Household Income',
                          'Income Per Capita',
#                           'County',
                          'Make',
                          'Model',
                          'Electric Vehicle Type']]
clean_merged_df
# Out:
#         Census Year  Postal Code  Population  Median Household Income  \
# 0              2022        98901       33106                    55536
# 1              2022        98901       33106                    55536
# 2              2022        98901       33106                    55536
# 3              2022        98901       33106                    55536
# 4              2022        98901       33106                    55536
# ...             ...          ...         ...                      ...
# 112241         2022        99131         122                    34081
# 112242         2022        99348        1590                    74211
# 112243         2022        98336         594                    76250
# 112244         2022        98935        4378                    60085
# 112245         2022        99179         568                    78906
#
#         Income Per Capita           Make           Model  \
# 0                 25237.0         NISSAN            LEAF
# 1                 25237.0          TESLA         MODEL 3
# 2                 25237.0     VOLKSWAGEN            ID.4
# 3                 25237.0          TESLA         MODEL 3
# 4                 25237.0  MERCEDES-BENZ         B-CLASS
# ...                   ...            ...             ...
# 112241            31798.0         NISSAN            LEAF
# 112242            32056.0      CHEVROLET            VOLT
# 112243            30549.0          HONDA         CLARITY
# 112244            18814.0          TESLA         MODEL 3
# 112245            46052.0           FORD  MUSTANG MACH-E
#
#                          Electric Vehicle Type
# 0               Battery Electric Vehicle (BEV)
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3               Battery Electric Vehicle (BEV)
# 4               Battery Electric Vehicle (BEV)
# ...                                        ...
# 112241          Battery Electric Vehicle (BEV)
# 112242  Plug-in Hybrid Electric Vehicle (PHEV)
# 112243  Plug-in Hybrid Electric Vehicle (PHEV)
# 112244          Battery Electric Vehicle (BEV)
# 112245          Battery Electric Vehicle (BEV)
#
# [112246 rows x 8 columns]

# %%
ev_count = clean_merged_df.groupby('Postal Code').count()
type_count = ev_count[['Electric Vehicle Type']]
type_count = type_count.reset_index()

# %%
df = clean_merged_df[['Postal Code','Population']]
df_per_cap = df.drop_duplicates()

# %%
merged_percapita = pd.merge(df_per_cap, type_count, on='Postal Code', how='outer')
merged_percapita
# Out:
#      Postal Code  Population  Electric Vehicle Type
# 0          98901       33106                     69
# 1          98237        4979                     21
# 2          98201       30587                    250
# 3          98021       34993                   1156
# 4          98203       36448                    344
# ..           ...         ...                    ...
# 491        99131         122                      1
# 492        99348        1590                      1
# 493        98336         594                      1
# 494        98935        4378                      1
# 495        99179         568                      1
#
# [496 rows x 3 columns]

# %%
merged_percapita['EV Population Percent'] = (merged_percapita['Electric Vehicle Type']/merged_percapita['Population'])*100
merged_percapita = merged_percapita.rename(columns = {'Electric Vehicle Type':'Electric Vehicle Count'})

# %%
merged_percapita.sort_values(by='EV Population Percent', ascending=False)
# Out:
#      Postal Code  Population  Electric Vehicle Count  EV Population Percent
# 344        98134         852                     158              18.544601
# 451        98833         153                      14               9.150327
# 153        98039        2923                     242               8.279165
# 441        98286         158                      11               6.962025
# 124        98072       25034                    1661               6.634976
# ..           ...         ...                     ...                    ...
# 492        99348        1590                       1               0.062893
# 437        98952        1724                       1               0.058005
# 411        98857        3545                       2               0.056417
# 403        98951       13145                       5               0.038037
# 494        98935        4378                       1               0.022841
#
# [496 rows x 4 columns]

# %%
#graph top ten zip codes 
merged_percapita_top10 = merged_percapita.nlargest(10,columns='EV Population Percent')

x_axis_list = np.arange(len(merged_percapita_top10['Postal Code']))
x_ticks = [value for value in x_axis_list]
y_axis = merged_percapita_top10['EV Population Percent']
plt.title('Top 10 Zipcodes per Capita EV Ownership')
plt.xlabel('Zipcode')
plt.ylabel('Ev Ownership Percentage')
plt.xticks(x_ticks, merged_percapita_top10['Postal Code'], rotation='vertical')
plt.bar(x_axis_list, y_axis)
plt.savefig('Graphs/top10-EVownership')
plt.show()

# %%
clean_ev_cen = ev_cen.groupby('Make').agg({'Income Per Capita':['median','mean'],
                           'Postal Code':lambda x: x.nunique()}).reset_index()
clean_ev_cen.columns = clean_ev_cen.columns.map('_'.join)
print(clean_ev_cen.shape)
clean_ev_cen_filtered = clean_ev_cen[clean_ev_cen['Postal Code_<lambda>']>10]
#                                      np.nanquantile(clean_ev_cen['Postal Code_<lambda>'],0.025)]
print(clean_ev_cen_filtered.shape)
# clean_ev_cen_filtered.sort_values('Income Per Capita_median')
# Out:
# (34, 4)
# (31, 4)

# %%
ev_sum = clean_ev_cen_filtered['Postal Code_<lambda>'].sum()
clean_ev_cen_filtered['Make Percent'] = (clean_ev_cen_filtered['Postal Code_<lambda>']/ev_sum)*100
clean_ev_cen_filtered = clean_ev_cen_filtered.sort_values(by='Make Percent')
clean_ev_cen_filtered.head()
# Out:
# /var/folders/q0/1ctrg7ln7537xxm0j8j094dm0000gn/T/ipykernel_1048/1721433677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_ev_cen_filtered['Make Percent'] = (clean_ev_cen_filtered['Postal Code_<lambda>']/ev_sum)*100
#          Make_  Income Per Capita_median  Income Per Capita_mean  \
# 10     GENESIS                   62999.0            63760.611111
# 8       FISKER                   52800.0            61512.736842
# 17       LEXUS                   56311.0            64853.969697
# 16  LAND ROVER                   75493.5            72068.052632
# 28      SUBARU                   60001.0            61104.016949
#
#     Postal Code_<lambda>  Make Percent
# 10                    15      0.230097
# 8                     18      0.276116
# 17                    28      0.429514
# 16                    32      0.490873
# 28                    46      0.705630

# %%
type_slp, type_int, type_r, type_p, type_stderr = stats.linregress(clean_ev_cen_filtered['Income Per Capita_median'],
                                                                  clean_ev_cen_filtered['Make Percent'])

# %%
plt.scatter(clean_ev_cen_filtered['Income Per Capita_median'], clean_ev_cen_filtered['Make Percent'])
type_line = type_slp * clean_ev_cen_filtered['Income Per Capita_median'] + type_int
plt.plot(clean_ev_cen_filtered['Income Per Capita_median'],type_line,'--',color='r')
plt.title('Relationship of Percentage of EV Make to Median Per Capita Income')
plt.ylabel('Percentage of EV Make')
plt.xlabel('Median Per Capita Income')
plt.savefig('Graphs/EV-make-pc-Income-line')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.scatter(clean_ev_cen_filtered['Income Per Capita_median'], clean_ev_cen_filtered['Make Percent'])
#       2 type_line = type_slp * clean_ev_cen_filtered['Income Per Capita_median'] + type_int
#       3 plt.plot(clean_ev_cen_filtered['Income Per Capita_median'],type_line,'--',color='r')
#
# NameError: name 'clean_ev_cen_filtered' is not defined

# %%
clean_ev_cen_filtered = clean_ev_cen_filtered.sort_values(by='Income Per Capita_median')

# %%
x_axis_list = np.arange(len(clean_ev_cen_filtered['Make_']))
x_ticks = [value for value in x_axis_list]
plt.title('Median Income for Most Popular EV Makes')
plt.xlabel('Make of EV')
plt.ylabel('Median Income Per Capita')
plt.xticks(x_ticks, clean_ev_cen_filtered['Make_'], rotation='vertical')
plt.bar(clean_ev_cen_filtered['Make_'], clean_ev_cen_filtered['Income Per Capita_median'])
plt.save_fig('Graphs/income_make_bar')
# Out:
# <BarContainer object of 31 artists>

# %%
clean_type_ev_cen = ev_cen.groupby(['Make','Electric Vehicle Type']).agg({'Income Per Capita':['median','mean'],
                           'Postal Code':lambda x: x.nunique()}).reset_index()
clean_type_ev_cen.columns = clean_type_ev_cen.columns.map('_'.join)
print(clean_ev_cen.shape)
clean_type_ev_cen_filtered = clean_type_ev_cen[clean_type_ev_cen['Postal Code_<lambda>']>50]
#                                      np.nanquantile(clean_ev_cen['Postal Code_<lambda>'],0.025)]
print(clean_type_ev_cen_filtered.shape)
clean_type_ev_cen_filtered
clean_type_ev_cen_filtered
# Out:
# (34, 4)
# (38, 5)
#             Make_                  Electric Vehicle Type_  \
# 0            AUDI          Battery Electric Vehicle (BEV)
# 1            AUDI  Plug-in Hybrid Electric Vehicle (PHEV)
# 4             BMW          Battery Electric Vehicle (BEV)
# 5             BMW  Plug-in Hybrid Electric Vehicle (PHEV)
# 6        CADILLAC  Plug-in Hybrid Electric Vehicle (PHEV)
# 7       CHEVROLET          Battery Electric Vehicle (BEV)
# 8       CHEVROLET  Plug-in Hybrid Electric Vehicle (PHEV)
# 9        CHRYSLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 10           FIAT          Battery Electric Vehicle (BEV)
# 12           FORD          Battery Electric Vehicle (BEV)
# 13           FORD  Plug-in Hybrid Electric Vehicle (PHEV)
# 15          HONDA  Plug-in Hybrid Electric Vehicle (PHEV)
# 16        HYUNDAI          Battery Electric Vehicle (BEV)
# 17        HYUNDAI  Plug-in Hybrid Electric Vehicle (PHEV)
# 18         JAGUAR          Battery Electric Vehicle (BEV)
# 19           JEEP  Plug-in Hybrid Electric Vehicle (PHEV)
# 20            KIA          Battery Electric Vehicle (BEV)
# 21            KIA  Plug-in Hybrid Electric Vehicle (PHEV)
# 24        LINCOLN  Plug-in Hybrid Electric Vehicle (PHEV)
# 25   LUCID MOTORS          Battery Electric Vehicle (BEV)
# 26  MERCEDES-BENZ          Battery Electric Vehicle (BEV)
# 27  MERCEDES-BENZ  Plug-in Hybrid Electric Vehicle (PHEV)
# 28           MINI          Battery Electric Vehicle (BEV)
# 29           MINI  Plug-in Hybrid Electric Vehicle (PHEV)
# 30     MITSUBISHI          Battery Electric Vehicle (BEV)
# 31     MITSUBISHI  Plug-in Hybrid Electric Vehicle (PHEV)
# 32         NISSAN          Battery Electric Vehicle (BEV)
# 33       POLESTAR          Battery Electric Vehicle (BEV)
# 34        PORSCHE          Battery Electric Vehicle (BEV)
# 35        PORSCHE  Plug-in Hybrid Electric Vehicle (PHEV)
# 36         RIVIAN          Battery Electric Vehicle (BEV)
# 37          SMART          Battery Electric Vehicle (BEV)
# 40          TESLA          Battery Electric Vehicle (BEV)
# 42         TOYOTA          Battery Electric Vehicle (BEV)
# 43         TOYOTA  Plug-in Hybrid Electric Vehicle (PHEV)
# 44     VOLKSWAGEN          Battery Electric Vehicle (BEV)
# 45          VOLVO          Battery Electric Vehicle (BEV)
# 46          VOLVO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#     Income Per Capita_median  Income Per Capita_mean  Postal Code_<lambda>
# 0                    63748.0            69694.487979                   224
# 1                    63748.0            69177.295681                   233
# 4                    67017.0            70668.909091                   182
# 5                    61597.0            66961.024993                   314
# 6                    45845.5            52690.898148                    85
# 7                    50946.0            56513.980099                   373
# 8                    46719.0            53021.017846                   383
# 9                    48511.0            56453.499156                   272
# 10                   55109.0            60309.051157                   219
# 12                   50901.0            56194.751848                   315
# 13                   46805.0            52114.197012                   362
# 15                   52478.0            58480.055767                   230
# 16                   52478.0            58983.944139                   246
# 17                   51688.0            57624.528481                   152
# 18                   60791.5            64517.169725                   122
# 19                   49978.0            56122.853275                   272
# 20                   51688.0            58006.987692                   326
# 21                   48549.0            56328.070204                   259
# 24                   48286.0            54617.173653                   115
# 25                   60554.5            68487.953125                    52
# 26                   66675.0            70147.068548                   117
# 27                   58143.0            65339.042969                   122
# 28                   60548.0            65450.675000                   152
# 29                   61300.0            67619.322917                   111
# 30                   51856.5            56265.625000                    52
# 31                   44650.0            50524.440385                   180
# 32                   55109.0            59918.290370                   378
# 33                   62388.0            66804.951526                   170
# 34                   80049.0            79035.825359                   127
# 35                   64239.0            71086.587940                   151
# 36                   52308.0            59929.688914                   211
# 37                   52308.0            60089.113553                   140
# 40                   61300.0            66454.135407                   454
# 42                   55710.0            61674.655172                    52
# 43                   48631.0            56411.323598                   366
# 44                   58469.0            63014.015556                   292
# 45                   65505.0            69598.897833                   167
# 46                   65505.0            69469.012240                   246

# %%
# plot box and whisker plot
# set x axis equal to the type of EV
# the boxes will include all of the makes
# set the y axis equal to the income per capita
